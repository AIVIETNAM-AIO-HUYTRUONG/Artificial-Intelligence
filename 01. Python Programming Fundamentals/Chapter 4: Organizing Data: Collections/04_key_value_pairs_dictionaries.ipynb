# %% [markdown]
# <a href="https://colab.research.google.com/github/AIVIETNAM-AIO-HUYTRUONG/Artificial-Intelligence/blob/basic/01.%20Python%20Programming%20Fundamentals/Chapter%204%3A%20Organizing%20Data%3A%20Collections/04_key_value_pairs_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Key Value Pairs: Dictionaries**
#
# - Khi tổ chức dữ liệu, có nhiều tình huống mà các thông tin riêng lẻ cần được liên kết với nhau nhưng không phụ thuộc vào một thứ tự cụ thể. Hãy tưởng tượng một cuốn từ điển: bạn tra một từ (key) để tìm định nghĩa của nó (value).
#
# - **Dictionary** trong Python cũng hoạt động theo cách tương tự, lưu trữ dữ liệu dưới dạng **các cặp khóa - giá trị (key-value pairs)**.
#
# - Dictionary đặc biệt hữu ích khi bạn cần truy xuất dữ liệu dựa trên một định danh **key** cụ thể thay vì vị trí của dữ liệu trong một chuỗi. Dictionary được định nghĩa bằng dấu ngoặc nhọn `{}`.

# %% [markdown]
# ## **1. Creating Dictionaries**
#
# - Bạn tạo một Dictionary bằng cách đặt các cặp **key-value** được phân tách bởi dấu phẩy bên trong dấu ngoặc nhọn `{}`. Mỗi cặp bao gồm một **v**, theo sau là dấu hai chấm `:` , rồi đến value tương ứng.

# %%
# An empty dictionary
empty_dict = {}

# A dictionary storing student grades
student_grades = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78
}

print(student_grades)
# Output: {'Alice': 85, 'Bob': 92, 'Charlie': 78}

# Keys can be different immutable types (strings, numbers, tuples)
mixed_keys = {
    "name": "Example Item",
    101: "Item ID",
    ("x", "y"): "Coordinates"
}
print(mixed_keys)
# Output: {'name': 'Example Item', 101: 'Item ID', ('x', 'y'): 'Coordinates'}
# Out:
# {'Alice': 85, 'Bob': 92, 'Charlie': 78}
# {'name': 'Example Item', 101: 'Item ID', ('x', 'y'): 'Coordinates'}

# %% [markdown]
# ### **1.1. Important Rules for Keys**
#
# 1. **Uniqueness**: Các **key** trong cùng một Dictionary phải là duy nhất. Nếu bạn thêm một **key** đã tồn tại, **value** cũ sẽ bị ghi đè bởi **value mới**.

# %%
student = {
    "Alice": 85
}

student["Alice"] = 95

print(student)
# Out:
# {'Alice': 95}

# %% [markdown]
# 2. **Immutability**:
#
#   - **Key** phải là một kiểu dữ liệu bất biến. Ví dụ, có thể sử dụng: `str` `int` `float` `tuple` (miễn là mọi phần tử bên trong cũng đều bất biến)
#   - Trong khi đó, **value** có thể thuộc bất kỳ kiểu dữ liệu nào.

# %% [markdown]
# ## **2. Accessing Values**
#
# - Bạn truy cập value tương ứng với một key bằng cách sử dụng dấu ngoặc vuông `[]`.
#
# - Cú pháp này khá giống với việc truy cập phần tử trong list, tuy nhiên thay vì sử dụng **index**, bạn sử dụng **key**.

# %%
student_grades = {"Alice": 85, "Bob": 92, "Charlie": 78}

# Get Bob's grade
bobs_grade = student_grades["Bob"]
print(f"Bob's grade is: {bobs_grade}")
# Output: Bob's grade is: 92
# Out:
# Bob's grade is: 92

# %%
# Trying to access a non-existent key causes an error
print(student_grades["David"]) # This would raise a KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1916/3112271927.py in <cell line: 0>()
#       1 # Trying to access a non-existent key causes an error
# ----> 2 print(student_grades["David"]) # This would raise a KeyError
#
# KeyError: 'David'

# %% [markdown]
# - Nếu bạn cố gắng truy cập một **key** không tồn tại trong dictionary, Python sẽ phát sinh `KeyError`. Chúng ta sẽ tìm hiểu cách xử lý những lỗi tiềm ẩn như vậy trong chương sau về **xử lý ngoại lệ (exception handling)**.
#
# - Một cách an toàn hơn để lấy value khi bạn không chắc **key** có tồn tại hay không là sử dụng method `get()`. Method này trả về `None`, hoặc một **default value** do bạn chỉ định, nếu không tìm thấy **key**, thay vì phát sinh lỗi.

# %%
student_grades = {"Alice": 85, "Bob": 92, "Charlie": 78}

# Get Alice's grade using get()
alice_grade = student_grades.get("Alice")
print(f"Alice's grade (using get): {alice_grade}")
# Output: Alice's grade (using get): 85

# Try to get David's grade (doesn't exist)
david_grade = student_grades.get("David")
print(f"David's grade (using get): {david_grade}")
# Output: David's grade (using get): None

# Provide a default value if the key is missing
eve_grade = student_grades.get("Eve", "Not Found")
print(f"Eve's grade (using get with default): {eve_grade}")
# Output: Eve's grade (using get with default): Not Found
# Out:
# Alice's grade (using get): 85
# David's grade (using get): None
# Eve's grade (using get with default): Not Found

# %% [markdown]
# ## **3. Adding and Modifying Pairs**
#
# - Việc thêm một **key-value pair** mới hoặc sửa `value` của một `key` đã có là rất đơn giản. Bạn dùng dấu `[]` ở bên trái của một phép gán

# %%
student_grades = {"Alice": 85, "Bob": 92}
print(f"Original grades: {student_grades}")

# Add a new student
student_grades["Charlie"] = 78
print(f"After adding Charlie: {student_grades}")

# Update Bob's grade
student_grades["Bob"] = 95
print(f"After updating Bob: {student_grades}")
# Out:
# Original grades: {'Alice': 85, 'Bob': 92}
# After adding Charlie: {'Alice': 85, 'Bob': 92, 'Charlie': 78}
# After updating Bob: {'Alice': 85, 'Bob': 95, 'Charlie': 78}

# %% [markdown]
# - Nếu key `"Charlie"` chưa tồn tại, một pair mới sẽ được thêm vào.
# - Nếu key `"Bob"` đã tồn tại, value tương ứng của nó sẽ được cập nhật.

# %% [markdown]
# ### **4. Removing Pairs**
#
# - Bạn có thể xóa **key-value pairs** bằng từ khóa `del` hoặc method `pop()`.

# %%
student_grades = {"Alice": 85, "Bob": 95, "Charlie": 78}
print(f"Initial dictionary: {student_grades}")

# Remove Charlie using del
del student_grades["Charlie"]
print(f"After deleting Charlie: {student_grades}")

# Remove Bob using pop() and get the removed value
bobs_removed_grade = student_grades.pop("Bob")
print(f"Removed Bob's grade: {bobs_removed_grade}")
print(f"Dictionary after popping Bob: {student_grades}")
# Out:
# Initial dictionary: {'Alice': 85, 'Bob': 95, 'Charlie': 78}
# After deleting Charlie: {'Alice': 85, 'Bob': 95}
# Removed Bob's grade: 95
# Dictionary after popping Bob: {'Alice': 85}

# %% [markdown]
# - `del` chỉ đơn giản là xóa item
#
# - Method `pop()` vừa xóa item vừa trả về value của nó, điều này có thể rất hữu ích.
#
# - Nếu bạn dùng `del` hoặc `pop()` với một key không tồn tại, bạn sẽ gặp lỗi **KeyError**

# %% [markdown]
# #### **4.1 Removing the Last Inserted Item: `popitem()`**
#
# - Kể từ Python 3.7, `popitem()` được đảm bảo sẽ loại bỏ và trả về một cặp key-value theo thứ tự **LIFO (Last In, First Out)**, nghĩa là nó xóa item được thêm vào cuối cùng.
# - Nếu dictionary rỗng, nó sẽ báo lỗi **KeyError**.

# %%
student_grades = {"Alice": 85, "Bob": 95, "Charlie": 78}
print(f"Initial dictionary: {student_grades}")

# Remove the last inserted item using popitem()
removed_item = student_grades.popitem()
print(f"Removed item: {removed_item}") # Output: ('Charlie', 78)
print(f"Dictionary after popitem(): {student_grades}")

# Try to popitem from an empty dictionary (will cause an error)
empty_dict = {}
# empty_dict.popitem() # Uncommenting this line causes a KeyError
# Out:
# Initial dictionary: {'Alice': 85, 'Bob': 95, 'Charlie': 78}
# Removed item: ('Charlie', 78)
# Dictionary after popitem(): {'Alice': 85, 'Bob': 95}

# %% [markdown]
# ### **5. Common Dictionary Operations**
#
# - Dictionaries đi kèm một số method rất hữu ích:
#
#   - `keys()`: trả về một view object hiển thị danh sách tất cả keys.
#   - `values()`: trả về một view object hiển thị danh sách tất cả values.
#   - `items()`: trả về một view object hiển thị danh sách các cặp key-value dưới dạng tuple.
#   - `len()`: không phải method mà là một **built-in function (hàm dựng sẵn)**, trả về **số lượng key-value pairs**.
#   - `in`: một operator dùng để kiểm tra xem một key có tồn tại trong dictionary hay không.

# %%
student_grades = {"Alice": 85, "Bob": 95, "Charlie": 78}

print(f"Keys: {student_grades.keys()}")
print(f"Values: {student_grades.values()}")
print(f"Items: {student_grades.items()}")
print(f"Number of students: {len(student_grades)}")

# Check if 'Alice' is in the dictionary
if "Alice" in student_grades:
    print("Alice is in the grades dictionary.")

# Check if 'David' is in the dictionary
if "David" not in student_grades:
    print("David is not in the grades dictionary.")
# Out:
# Keys: dict_keys(['Alice', 'Bob', 'Charlie'])
# Values: dict_values([85, 95, 78])
# Items: dict_items([('Alice', 85), ('Bob', 95), ('Charlie', 78)])
# Number of students: 3
# Alice is in the grades dictionary.
# David is not in the grades dictionary.

# %% [markdown]
# ## **6. Conclusion**
#
# - Dictionary cung cấp một cách linh hoạt để tổ chức dữ liệu khi thứ tự của dữ liệu không phải là yếu tố quan trọng, nhưng khả năng truy xuất nhanh dựa trên một **key** lại là yêu cầu chính.
#
# - Nhờ khả năng lưu trữ dữ liệu dưới dạng các cặp **key-value**, hỗ trợ truy xuất nhanh, thêm, cập nhật và xóa dữ liệu dễ dàng, Dictionary đã trở thành một trong những cấu trúc dữ liệu được sử dụng phổ biến nhất trong Python.
